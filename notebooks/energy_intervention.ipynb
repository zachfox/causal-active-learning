# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lingam
import graphviz
from tqdm import tqdm

from lingam.utils import make_prior_knowledge

from sklearn import preprocessing
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KernelDensity 
from sklearn.decomposition import PCA

import netcomp as nc

from rdkit import Chem
from rdkit.Chem import Descriptors

import src.model_utils as mu
import src.features.qm9_utils as qu

import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=FutureWarning) 
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# # Molecular intervention and discovery using the actively-learned dataset

# %% [markdown]
# ## Load the actively learned dataset and generate causal diagrams

# %%
data_path = '../data/processed/'
figure_path = '../reports/figures/'

# %%
# load the actively-learned dataset
active_df = pd.read_csv(os.path.join(data_path,'sample_active_df.csv'),index_col='Unnamed: 0')

# %%
# get the energies from the QM9 dataset
qm9_path = '/Users/z6f/projects/causal_ml/data/dsgdb9xyz/*.xyz'
smiles = []; dipole_moments = []; polarizability = []; 
gap = []; 
filenames = glob.glob(qm9_path)
for file in filenames:
    mol_xyz = qu.parse_xyz(file)
    smiles.append(mol_xyz['smiles'])
    dipole_moments.append(mol_xyz['mu'])
    polarizability.append(mol_xyz['alpha'])
    gap.append(mol_xyz['gap'])

gap = dict(zip(smiles,gap))

# %%
# add the energies to the active dataset 
active_df['gap'] = active_df['smiles'].map(gap)

# %%
# remove excess columns
df = active_df.drop(labels=['smiles','dipole'], axis='columns', inplace=False)
X = df.to_numpy()
target_column_ind = list(df.columns).index('gap')

# perform causal inference 
model = mu.causal_inference(X, target_col=target_column_ind)

# look at the DAG 
d = mu.make_graph(model.adjacency_matrix_, labels=list(df.columns))
# d.render(os.path.join(figure_path,'reports/figures/active_subset_graph'))

# %%
# !open ../reports/figures/reports/figures/active_subset_graph.pdf

# %%
# sort the df by homo lumo gap
sorted_homo_lumo = df.sort_values(by=['gap'])
sorted_homo_lumo = sorted_homo_lumo[:15]

# %%
lr = LinearRegression()
reg = lr.fit(X[:,:-1],X[:,-1])

# %% [markdown]
# ## Get a regressor to perform optimal interventions

# %%
# Get random forest model

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 1, stop = 6, num = 6)]
# quality of split
#criterion= ['squared_error']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(2, 5, num = 10)]
max_depth.append(None)
# max features
#max_features=['auto','sqrt','log2']
# Minimum number of samples required to split a node
min_samples_split = [2, 3, 4]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True,False]
# Create the random grid
tuned_parameters = {'n_estimators': n_estimators,'max_depth': max_depth,
                'min_samples_split': min_samples_split,'min_samples_leaf': min_samples_leaf,'bootstrap': bootstrap}

forest = RandomizedSearchCV(ExtraTreesRegressor(random_state=1),tuned_parameters,verbose=10,cv=10,n_jobs=-1)#,scoring=scores)

forest.fit(X[:,:-1], X[:,-1])
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV 1/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 1/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.185 total time=   0.0s
# [CV 9/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 9/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.275 total time=   0.0s
# [CV 10/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 10/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.264 total time=   0.0s
# [CV 1/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 1/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.034 total time=   0.0s
# [CV 2/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 2/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.377 total time=   0.0s
# [CV 3/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 3/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.082 total time=   0.0s
# [CV 4/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 4/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.153 total time=   0.0s
# [CV 5/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 5/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.307 total time=   0.0s
# [CV 6/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 6/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.142 total time=   0.0s
# [CV 7/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 7/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.266 total time=   0.0s
# [CV 8/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 8/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.188 total time=   0.0s
# [CV 9/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 9/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.238 total time=   0.0s
# [CV 10/10; 2/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 10/10; 2/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.074 total time=   0.0s
# [CV 1/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 1/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.200 total time=   0.0s
# [CV 2/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 2/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.417 total time=   0.0s
# [CV 3/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 4/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 3/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.193 total time=   0.0s
# [CV 4/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 4/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.299 total time=   0.0s
# [CV 4/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.297 total time=   0.0s
# [CV 5/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 5/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.383 total time=   0.0s
# [CV 6/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 7/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 3/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 6/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.311 total time=   0.0s
# [CV 8/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 5/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 3/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.115 total time=   0.0s
# [CV 6/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 5/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.337 total time=   0.0s
# [CV 8/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.321 total time=   0.0s
# [CV 9/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 6/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.264 total time=   0.0s
# [CV 9/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.281 total time=   0.0s
# [CV 10/10; 3/10] START bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5
# [CV 7/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.404 total time=   0.0s
# [CV 1/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 2/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 1/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.110 total time=   0.0s
# [CV 2/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 2/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.373 total time=   0.0s
# [CV 3/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 2/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.340 total time=   0.0s
# [CV 3/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.176 total time=   0.0s
# [CV 4/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 10/10; 3/10] END bootstrap=False, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=5;, score=0.249 total time=   0.0s
# [CV 5/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 6/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 4/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.208 total time=   0.0s[CV 5/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.319 total time=   0.0s
#
# [CV 6/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.179 total time=   0.0s
# [CV 7/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 8/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 7/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.349 total time=   0.0s
# [CV 9/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 8/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.283 total time=   0.0s
# [CV 10/10; 4/10] START bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1
# [CV 1/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 10/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.056 total time=   0.0s
# [CV 2/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 9/10; 4/10] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=1;, score=0.313 total time=   0.0s
# [CV 3/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 7/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 4/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 2/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.429 total time=   0.0s
# [CV 5/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 7/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.363 total time=   0.0s
# [CV 3/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.180 total time=   0.0s
# [CV 1/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.142 total time=   0.0s
# [CV 7/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 6/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 8/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 9/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 4/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.286 total time=   0.0s
# [CV 7/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.419 total time=   0.0s
# [CV 5/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.401 total time=   0.0s
# [CV 10/10; 5/10] START bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5
# [CV 9/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.251 total time=   0.0s
# [CV 1/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 8/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.260 total time=   0.0s
# [CV 2/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 3/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 4/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 6/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.306 total time=   0.0s
# [CV 3/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.345 total time=   0.0s
# [CV 5/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 2/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.459 total time=   0.0s
# [CV 6/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 10/10; 5/10] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=5;, score=0.268 total time=   0.0s
# [CV 4/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.379 total time=   0.0s
# [CV 1/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.295 total time=   0.0s
# [CV 5/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.502 total time=   0.0s
# [CV 7/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 6/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.354 total time=   0.0s
# [CV 9/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 8/10; 1/10] START bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6
# [CV 1/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 7/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.420 total time=   0.0s
# [CV 8/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 3/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 9/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.367 total time=   0.0s
# [CV 10/10; 6/10] START bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3
# [CV 5/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 8/10; 1/10] END bootstrap=False, max_depth=2, min_samples_leaf=4, min_samples_split=4, n_estimators=6;, score=0.273 total time=   0.0s
# [CV 1/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.187 total time=   0.0s
# [CV 2/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 10/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.399 total time=   0.0s
# [CV 7/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 9/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 8/10; 6/10] END bootstrap=True, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=3;, score=0.342 total time=   0.0s
# [CV 2/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.303 total time=   0.0s
# [CV 1/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 3/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 5/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.291 total time=   0.0s
# [CV 6/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 9/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.247 total time=   0.0s
# [CV 10/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 3/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.082 total time=   0.0s
# [CV 4/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 1/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.034 total time=   0.0s
# [CV 2/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 4/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.153 total time=   0.0s
# [CV 3/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.139 total time=   0.0s
# [CV 5/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 4/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 2/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.377 total time=   0.0s
# [CV 10/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.229 total time=   0.0s
# [CV 7/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 5/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.307 total time=   0.0s
# [CV 6/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 9/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 6/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.253 total time=   0.0s
# [CV 1/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 9/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.238 total time=   0.0s
# [CV 10/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 7/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.372 total time=   0.0s
# [CV 8/10; 7/10] START bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5
# [CV 3/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 10/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.085 total time=   0.0s
# [CV 7/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.258 total time=   0.0s
# [CV 8/10; 8/10] START bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1
# [CV 5/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 1/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.282 total time=   0.0s
# [CV 2/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 8/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.189 total time=   0.0s
# [CV 6/10; 8/10] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=1;, score=0.142 total time=   0.0s
# [CV 4/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.265 total time=   0.0s
# [CV 7/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 5/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.476 total time=   0.0s
# [CV 6/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 9/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 8/10; 7/10] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=4, n_estimators=5;, score=0.240 total time=   0.0s
# [CV 3/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.345 total time=   0.0s
# [CV 4/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 10/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 2/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.461 total time=   0.0s
# [CV 6/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.401 total time=   0.0s
# [CV 1/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 4/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.366 total time=   0.0s
# [CV 2/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 9/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.413 total time=   0.0s
# [CV 3/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 10/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.443 total time=   0.0s
# [CV 7/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.448 total time=   0.0s
# [CV 8/10; 9/10] START bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3
# [CV 4/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 5/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 6/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 7/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 1/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.397 total time=   0.0s
# [CV 8/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 8/10; 9/10] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=3;, score=0.392 total time=   0.0s
# [CV 2/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.581 total time=   0.0s
# [CV 9/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 10/10; 10/10] START bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6
# [CV 4/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.531 total time=   0.0s
# [CV 6/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.555 total time=   0.0s
# [CV 3/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.511 total time=   0.0s
# [CV 5/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.597 total time=   0.0s
# [CV 7/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.504 total time=   0.0s
# [CV 10/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.610 total time=   0.0s
# [CV 9/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.490 total time=   0.0s
# [CV 8/10; 10/10] END bootstrap=False, max_depth=None, min_samples_leaf=1, min_samples_split=4, n_estimators=6;, score=0.647 total time=   0.0s
# RandomizedSearchCV(cv=10, estimator=ExtraTreesRegressor(random_state=1),
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [2, 2, 2, 3, 3, 3, 4, 4, 4,
#                                                       5, None],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': [1, 2, 3, 4, 5, 6]},
#                    verbose=10)

# %%
# now, we want to find the variables that have the largest impact on the output
ce = lingam.CausalEffect(model) 
# needed to do this manually
effects = ce.estimate_effects_on_prediction(X, 9, forest)
print(list(df.columns))
print(np.array((df.columns))[np.argsort(np.abs(effects[:,1]-effects[:,0]))[::-1]])
# Out:
# ['NHOHCount', 'NumAliphaticCarbocycles', 'NumHeteroatoms', 'NOCount', 'RingCount', 'NumValenceElectrons', 'HeavyAtomMolWt', 'ExactMolWt', 'MaxPartialCharge', 'gap']
# ['ExactMolWt' 'HeavyAtomMolWt' 'NumAliphaticCarbocycles' 'NOCount'
#  'NumHeteroatoms' 'NHOHCount' 'MaxPartialCharge' 'RingCount'
#  'NumValenceElectrons' 'gap']

# %%
# example finding the intervention on NHOH count that sets the homo lumo gap to .33
desired_output=.33
feat_to_change=0

X_int = sorted_homo_lumo.to_numpy()
ce = lingam.CausalEffect(model) 
ce.estimate_optimal_intervention(X_int,-1,reg, feat_to_change, desired_output)
# Out:
# -28.41357398582238

# %% [markdown]
# ## Looping over subsets

# %%
# columns to keep
columns = ['smiles','NOCount','ExactMolWt','NumValenceElectrons', 'NHOHCount',
           'NumHeteroatoms','HeavyAtomMolWt','RingCount','MaxPartialCharge',
           'NumAliphaticCarbocycles']

subsets = []
for i in range(3):
    subsets.append(pd.read_csv(os.path.join(data_path,'split_class_{0}.csv'.format(i)))[columns])
    subsets[-1]['gap'] = subsets[-1]['smiles'].map(gap)
# and the active df
active_df = pd.read_csv(os.path.join(data_path,'sample_active_df.csv'),index_col='Unnamed: 0')

# add the energies to the active dataset 
active_df['gap'] = active_df['smiles'].map(gap)
subsets.append(active_df[columns])

# %%
X.shape
# Out:
# (1201, 9)

# %%
all_subset_variables = []
all_regressors = []
all_causal = []

K = 3 # number of variables to keep
target_gap_value = 5 
gap_ind = 8 
all_intervened_X = []
all_feats_to_intervene = []
for subset in tqdm(subsets):
    # put data in the right frame
    df = subset.drop(labels='smiles', axis='columns', inplace=False)
    X = df.to_numpy()
    
    # get a causal model 
    causal_model = mu.causal_inference(X)
    all_causal.append(causal_model)
    
    # get regressor model 
    lr = LinearRegression()
    regressor = lr.fit(X[:,:-1],X[:,-1]) # linear regression to be consistent
    all_regressors.append(regressor)
    
    # find variable(s) which cause the largest change in the target output
    ce = lingam.CausalEffect(causal_model) 
    
    # needed to do this manually
    effects = ce.estimate_effects_on_prediction(X, gap_ind, regressor)
    feats_to_intervene = np.argsort(np.abs(effects[:,1]-effects[:,0]))[::-1][:K]
    all_feats_to_intervene.append(feats_to_intervene)
    all_subset_variables.append(np.array((df.columns))[feats_to_intervene])
    
    # find the optimal intervention for each molecule,variable pair
    # be careful, `intervened_X` is not representative of real molecules; to make the real 
    # molecules you have to replace the appropriate column of X with the corresponding column in 
    # intervened X
    intervened_X = np.copy(X)
    for feat in feats_to_intervene:        
        for k in range(X.shape[0]):
            intervened_X[k,feat] = ce.estimate_optimal_intervention(X[k,:].reshape(1, -1), gap_ind,
                                                                    regressor, feat, target_gap_value) 
    
    all_intervened_X.append(intervened_X)
# Out:
# 100%|██████████| 4/4 [01:45<00:00, 26.43s/it]

# %%
for i,subset in enumerate(subsets):
    df = subset.drop(labels='smiles', axis='columns', inplace=False)
    X = df.to_numpy()
    f,ax = plt.subplots(1,3,figsize=(6,2))
    for j,feature in enumerate(all_subset_variables[i]):
        ax[j].hist(df[feature].to_numpy(),alpha=0.5,label='original')
        ax[j].hist(all_intervened_X[i][:,j],alpha=0.5,label='intervened')
        ax[j].set_xlabel(feature)
    ax[0].set_ylabel('frequency')
    #ax[0].legend()
    f.tight_layout()

# %%
target_values = np.linspace(2,6,50)
interventions = []
feat = 4
for value in target_values:
    interventions.append(ce.estimate_optimal_intervention(X[5,:].reshape(1,-1), gap_ind,
                                    regressor, feat, value))

# %% [markdown]
# ## Load the active learning dataset and the searchable dataset

# %%
reference_df = pd.read_csv(os.path.join(data_path,'sousa_molecules.csv'))
all_intervened_X = np.array(all_intervened_X[-1])

# %%
# make sure that we have the right columns
possible_columns = ['smiles',
 'NOCount',
 'ExactMolWt',
 'NumValenceElectrons',
 'NHOHCount',
 'NumHeteroatoms',
 'HeavyAtomMolWt',
 'RingCount',
 'MaxPartialCharge',
 'NumAliphaticCarbocycles']

# replace active DataFrame with intervened molecules. 
intervened_df = active_df.copy()
intervened_df['NumAliphaticCarbocycles'] = np.abs(all_intervened_X[:,8])

X_active = intervened_df[possible_columns].drop(labels='smiles', axis='columns', inplace=False).to_numpy()
X_active_raw = active_df[possible_columns].drop(labels='smiles', axis='columns', inplace=False).to_numpy() 
X_possible = reference_df[possible_columns].drop(labels='smiles', axis='columns', inplace=False).to_numpy()

# %%
reference_df
# Out:
#       Unnamed: 0  ExactMolWt   TPSA  MolLogP  NumValenceElectrons  \
# 0              0  230.001368  34.89  2.78380                   74
# 1              1  226.056469  49.81  2.96758                   78
# 2              2   94.078250   0.00  1.97590                   38
# 3              3  201.101445  55.63  1.15570                   76
# 4              4  235.098172  91.51  0.40617                   88
# ...          ...         ...    ...      ...                  ...
# 9394        9394  119.073499  12.03  1.28980                   46
# 9395        9395  168.126263  24.50  0.37410                   68
# 9396        9396  191.094629  29.54  2.34172                   74
# 9397        9397  136.074896  31.20  0.92720                   52
# 9398        9398   98.036779  26.30  0.17930                   38
#
#       NumRadicalElectrons  MaxPartialCharge  NHOHCount  NOCount  \
# 0                       0          0.166078          0        3
# 1                       0          0.104644          2        2
# 2                       0          0.029335          0        0
# 3                       0          0.224400          1        5
# 4                       0          0.214329          3        7
# ...                   ...               ...        ...      ...
# 9394                    0          0.021143          1        1
# 9395                    0          0.073865          1        3
# 9396                    0          0.413774          0        3
# 9397                    0          0.148381          0        4
# 9398                    0          0.308866          0        2
#
#       NumAromaticRings  ...  NumAliphaticHeterocycles  NumAliphaticRings  \
# 0                    1  ...                         0                  1
# 1                    2  ...                         0                  1
# 2                    0  ...                         0                  0
# 3                    2  ...                         1                  1
# 4                    2  ...                         0                  0
# ...                ...  ...                       ...                ...
# 9394                 1  ...                         1                  1
# 9395                 0  ...                         3                  3
# 9396                 1  ...                         1                  1
# 9397                 0  ...                         2                  2
# 9398                 0  ...                         1                  2
#
#       NumAromaticCarbocycles  NumAromaticHeterocycles  \
# 0                          0                        1
# 1                          1                        1
# 2                          0                        0
# 3                          0                        2
# 4                          0                        2
# ...                      ...                      ...
# 9394                       1                        0
# 9395                       0                        0
# 9396                       1                        0
# 9397                       0                        0
# 9398                       0                        0
#
#       NumSaturatedCarbocycles  NumSaturatedHeterocycles  NumSaturatedRings  \
# 0                           0                         0                  0
# 1                           0                         0                  0
# 2                           0                         0                  0
# 3                           0                         0                  0
# 4                           0                         0                  0
# ...                       ...                       ...                ...
# 9394                        0                         0                  0
# 9395                        0                         3                  3
# 9396                        0                         1                  1
# 9397                        0                         0                  0
# 9398                        1                         1                  2
#
#       HeavyAtomMolWt                           smiles    dipole
# 0            223.018       O=C1C=C(n2cnc(Cl)c2Cl)CCC1  3.910293
# 1            216.224       N#Cc1c(N)sc2c1-c1ccccc1CC2  4.066508
# 2             84.077                      C#CCC(=C)CC  0.401645
# 3            190.145         c1cncc(-c2nnc3n2CCCN3)c1  5.372851
# 4            225.146  [H]/N=C(/Cn1cncn1)NNc1cccc(F)n1  5.290357
# ...              ...                              ...       ...
# 9394         110.095                  c1ccc2c(c1)CNC2  1.077136
# 9395         152.112   C1CCN2C[C@H]3CON[C@H]3[C@H]2C1  1.693313
# 9396         178.126            Cc1ccc(N2CCCOC2=O)cc1  4.970623
# 9397         128.094                CN1N=NN2CC=CC=C12  2.087692
# 9398          92.053            O=C1OC[C@H]2C[C@@H]12  4.665583
#
# [9399 rows x 27 columns]

# %%
# Compare the chemical space of the active data set an searchable data set
reducer = PCA(n_components=None, svd_solver='full')
reducer.fit(X_active)
embedding = reducer.transform(X_active)
embedding_possible = reducer.transform(X_possible)

# %%
# Sort the available molecules by their homo-lumo gap. 
columns = ['smiles',
 'NOCount',
 'ExactMolWt',
 'NumValenceElectrons',
 'NHOHCount',
 'NumHeteroatoms',
 'HeavyAtomMolWt',
 'RingCount',
 'MaxPartialCharge',
 'NumAliphaticCarbocycles',
 'dipole']

X_rf = active_df[columns].drop(labels='smiles', axis='columns', inplace=False).to_numpy() 

regr,score = mu.fit_random_forest(X_rf, False, False)

# %%
# Homo-lumo gap of the intervened molecules
gap_intervened = regr.predict(X_active) 
inds = np.argsort(gap_intervened) 
X_intervened_sorted = X_active[inds,:]

# %%
# sort the reference molecules by dipole moment
gap = reference_df['gap'].to_numpy()
inds = np.argsort(gap) 
X_reference_sorted = X_possible[inds,:]

# also sort the reference data frame 
reference_df_sorted = reference_df.sort_values(by=['gap'])
active_df_sorted = active_df.copy()
active_df_sorted['intervened_gap'] = gap_intervened
active_df_sorted = active_df_sorted.sort_values(by=['intervened_gap'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/causal_zf/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gap'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 # sort the reference molecules by dipole moment
# ----> 2 gap = reference_df['gap'].to_numpy()
#       3 inds = np.argsort(gap)
#       4 X_reference_sorted = X_possible[inds,:]
#
# File ~/anaconda3/envs/causal_zf/lib/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/causal_zf/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'gap'

# %%
# find the closest molecules - slow computation. can skip to next cell
distances = np.zeros((X_intervened_sorted.shape[0],X_reference_sorted.shape[0]))
for i in range(X_intervened_sorted.shape[0]):
    for j in range(X_reference_sorted.shape[0]):
        distances[i,j] = np.sum( (X_intervened_sorted[i,:]/X_intervened_sorted.max(axis=0)
                                  - X_reference_sorted[j,:]/X_reference_sorted.max(axis=0))**2 )

# %%
np.save('molecule_distances_sorted_sousa_hlgap',distances)

# %%
distances = np.load('molecule_distances_sorted_sousa_hlgap.npy')

# %%
f,ax = plt.subplots(figsize=(4,3))
imax = ax.imshow(distances,aspect='auto',cmap='Blues')
ax.set_xlabel('known molecules')
ax.set_ylabel('intervened molecules')
f.colorbar(imax,label='distance')
# f.savefig('figures/molecule distances_sousa.svg')

# %%
k=3
smiles_df = mu.get_top_k_close_molecules(k, distances,
                                      reference_df_sorted, active_df_sorted)

# %%
smiles_df
# Out:
#                 original               closest_0  \
# 0        OCC1C(C#N)C1C#N  [H]/N=C(/N)[C@H](C)C#C
# 1     CCC12CC(C1)(N2)C#N      CN1CCC(C(=O)O)=C1O
# 2       CN=C1C=COC(C)=N1      CN1CCC(C(=O)O)=C1O
# 3       CC1=CC2NC2C11CO1            CO[C@H](C)CN
# 4      O=CC1=NC=CC(=O)N1      CN1CCC(C(=O)O)=C1O
# ...                  ...                     ...
# 1196   O=CC12C=CC3C1OC23  Cc1nn(C)c(-n2cncn2)c1N
# 1197       O=CC1CC2CN2C1               CCN1CCCC1
# 1198      CC1CC2C3OC3C12              CCC(C#N)CC
# 1199      CC1N2CC2C11CN1     COC(=O)N1C=CC=CC=C1
# 1200      CC1C2CC1(C)CO2  Cc1nn(C)c(-n2cncn2)c1N
#
#                                      closest_1  \
# 0     O=C1N=C(O)[C@H]2[C@H]1[C@H]1C=C[C@@H]2O1
# 1                                    C1COCCOC1
# 2                                    C1COCCOC1
# 3                 O=C(CCl)N1C(=O)N=C(O)[C@H]1O
# 4     O=C1N=C(O)[C@H]2[C@H]1[C@H]1C=C[C@@H]2O1
# ...                                        ...
# 1196                       Clc1snnc1CSCc1ccco1
# 1197                              C[C@@H]1CN1C
# 1198                               C#CC=NN1CC1
# 1199                              C[C@@H]1CN1C
# 1200                       Clc1snnc1CSCc1ccco1
#
#                            closest_2  closest_0_dipole  closest_1_dipole  \
# 0                    C#C[C@@H](CC)CO          2.243610          6.388642
# 1              COCCc1noc(-c2cnsn2)n1          3.402617          0.774960
# 2              COCCc1noc(-c2cnsn2)n1          3.402617          0.774960
# 3     O=C(F)[C@@]1(F)OC(F)(F)OC1(F)F          0.578708          6.826481
# 4             [H]/N=C(/N)[C@H](C)C#C          3.402617          6.388642
# ...                              ...               ...               ...
# 1196                    C[C@@H]1CN1C          1.636387          2.658313
# 1197             COC(=O)N1C=CC=CC=C1          0.891469          1.174334
# 1198           C[C@H]1[C@H](O)C1(C)C          3.849255          0.205079
# 1199                       CCN1CCCC1          2.019708          1.174334
# 1200    OCCCN(c1ccccc1)[C@H]1C=CCCC1          1.636387          2.658313
#
#       closest_2_dipole  closest_0_distance  closest_1_distance  \
# 0             1.622862            0.028199            0.028300
# 1             1.048269            0.123425            0.143183
# 2             1.048269            0.123350            0.143033
# 3             0.854660            0.107312            0.108321
# 4             2.243610            0.021574            0.039040
# ...                ...                 ...                 ...
# 1196          1.174334            0.011459            0.013935
# 1197          2.019708            0.042711            0.057951
# 1198          1.497698            0.038934            0.057722
# 1199          0.891469            0.033251            0.082498
# 1200          2.841981            0.017714            0.018807
#
#       closest_2_distance
# 0               0.042143
# 1               0.150786
# 2               0.150549
# 3               0.153532
# 4               0.044905
# ...                  ...
# 1196            0.025370
# 1197            0.064077
# 1198            0.061455
# 1199            0.088321
# 1200            0.025433
#
# [1201 rows x 10 columns]

# %%
# compare distances and tanimoto of base molecule 
min_distances = np.min(distances,axis=1)

# %%
# get the fingerprints for each column
all_fingerprints = [mu.get_data_fingerprints(smiles_df, 'original')]
for i in range(k):
    all_fingerprints.append(mu.get_data_fingerprints(smiles_df,f"closest_{i}"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # get the fingerprints for each column
# ----> 2 reload(mu)
#       3 all_fingerprints = [mu.get_data_fingerprints(smiles_df, 'original')]
#       4 for i in range(k):
#
# NameError: name 'reload' is not defined

# %%
reload(mu)
all_similarities = []
for i in range(k):
    all_similarities.append(mu.get_tanimoto_similarities(all_fingerprints[0], all_fingerprints[i+1]))
similarities = np.array(all_similarities).T

# %%
# find the molecules that are most similar 
sorted_similarity = smiles_df.copy()
mean_similarity = np.mean(similarities,axis=1)
for i,similarity in enumerate(similarities.T):
    sorted_similarity[f'similarity_{i}'] = similarity
sorted_similarity['mean_similarity'] = mean_similarity 
sorted_similarity.sort_values(by=['similarity_0'],ascending=False, inplace=True)

# %%
f,ax = plt.subplots(figsize=(3,2))
kde = KernelDensity(kernel='gaussian', bandwidth=0.008).fit(mean_similarity.reshape(-1,1))
xplot = np.linspace( np.min(mean_similarity)*.9, np.max(mean_similarity)*1.01, 100).reshape(-1,1)
ax.plot(xplot, np.exp(kde.score_samples(xplot)),color='k',linewidth=1)
_ = ax.hist(mean_similarity, bins=35, density=True,alpha=.5,facecolor='gray')
ax.spines[['right', 'top']].set_visible(False)

ax.set_xlabel('Tanimoto similarity')
ax.set_ylabel('fraction molecules') 
f.savefig('figures/tanimoto_similarity.svg')

# %%
f,ax = plt.subplots(figsize=(2.5,2))
ax.scatter(mean_similarity,min_distances,s=3,c='darkred')
ax.set_xlabel('Tanimoto similarity')
ax.set_ylabel('distance in feature space')
f.savefig('figures/reference_feature_scatter.svg')

# %%
# see how much the molecules move in chemical space 
sorted_index = np.array(sorted_similarity.index)

# get the chemcical space of the active dataframe
active_fp = np.array(mu.get_data_fingerprints(active_df, 'smiles'))
reducer = PCA(n_components=None, svd_solver='full')
reducer.fit(active_fp)
embedding = reducer.transform(active_fp)

before = reducer.transform(np.array(all_fingerprints[0])[sorted_index])
after = reducer.transform(np.array(all_fingerprints[1])[sorted_index])

# %%
reload(mu)
f,ax = plt.subplots(1,1,figsize=(3.5,3))
binsxa,binsya,hist_active = mu.getcolordensity_contour(embedding[:,0], embedding[:,1])
start,stop = 10,20

ax.contourf(binsxa, binsya, hist_active, cmap='Reds', levels=15)
ax.scatter(before[start:stop,0], before[start:stop,1],c='k',s=12, marker='s')
ax.scatter(after[start:stop,0], after[start:stop,1],c='g',s=12)
nplot = stop-start
for i in range(start,stop):
    ax = mu.plot_path_between(before[i,:2], after[i,:2], ax)
    
ax.set_xlabel(r'$\phi_1$',fontsize=14)
ax.set_ylabel(r'$\phi_2$',fontsize=14)
f.tight_layout()
# f.savefig('figures/intervened_molecules.pdf')

# draw the molecules
for i in range(nplot): 
    mu.draw_molecules([sorted_similarity['original'].to_list()[i], 
                       sorted_similarity['closest_0'].to_list()[i]],
                   prefix=f'./figures/dipole_intervene/molecule_{i}')
    dipole_og = merged_df['dipole'][i]
    dipole_closest = merged_df['closest_0_dipole'][i]
    print(f'dipoles {i}: {dipole_og} , {dipole_closest}')
# Out:
# dipoles 0: 2.7531 , 0.077471
# dipoles 1: 2.2999 , 1.777215
# dipoles 2: 1.4402 , 0.077471
# dipoles 3: 0.8254 , 2.441781
# dipoles 4: 1.767 , 2.749288
# dipoles 5: 3.3629 , 1.687856
# dipoles 6: 2.4972 , 0.077471
# dipoles 7: 1.6848 , 5.07004
# dipoles 8: 3.325 , 0.961773
# dipoles 9: 0.2279 , 0.077471

# %%
# predict the intervened molecule's dipole using rf:
columns = ['smiles',
 'NOCount',
 'ExactMolWt',
 'NumValenceElectrons',
 'NHOHCount',
 'NumHeteroatoms',
 'HeavyAtomMolWt',
 'RingCount',
 'MaxPartialCharge',
 'NumAliphaticCarbocycles',
 'dipole']

X_rf = active_df[columns].drop(labels='smiles', axis='columns', inplace=False).to_numpy() 

regr,score = mu.fit_random_forest(X_rf, False, False)

# %%
# predict the dipole in the intervened molecule
intervened_X = intervened_df[columns].drop(labels=['smiles','dipole'], axis='columns', inplace=False).to_numpy()
intervened_df['dipole_pred'] = regr.predict(intervened_X)

# %%
# do a data join on smiles
merged_df = sorted_similarity.merge(intervened_df,left_on='original',right_on='smiles')

# %%
merged_df['delta_dipole'] = merged_df['dipole_pred'] - merged_df['dipole']

# %%
colors = ['firebrick','royalblue','darkviolet']
f,ax = plt.subplots(figsize=(3,2))
kde = KernelDensity(kernel='tophat', bandwidth=.5).fit(merged_df['dipole'].to_numpy().reshape(-1,1))
xplot = np.linspace( np.min(merged_df['dipole'].to_numpy()), np.max(merged_df['dipole'].to_numpy()), 100).reshape(-1,1)
ax.plot(xplot, np.exp(kde.score_samples(xplot)),color=colors[0],label='original')

kde = KernelDensity(kernel='tophat', bandwidth=.5).fit(merged_df['dipole_pred'].to_numpy().reshape(-1,1))
xplot = np.linspace( np.min(merged_df['dipole_pred'].to_numpy()), np.max(merged_df['dipole_pred'].to_numpy()), 100).reshape(-1,1)
ax.plot(xplot, np.exp(kde.score_samples(xplot)),color=colors[1],label='intervened')

kde = KernelDensity(kernel='tophat', bandwidth=.2).fit(merged_df['closest_0_dipole'].to_numpy().reshape(-1,1))
xplot = np.linspace( np.min(merged_df['closest_0_dipole'].to_numpy()), np.max(merged_df['closest_0_dipole'].to_numpy()), 100).reshape(-1,1)
#ax.plot(xplot, np.exp(kde.score_samples(xplot)),color=colors[2])


#_ = ax.hist(merged_df['dipole'].to_numpy(), bins=35, density=True,alpha=.1,color=colors[0])
#_ = ax.hist(merged_df['dipole_pred'].to_numpy(), bins=35, density=True,alpha=.1,color=colors[1])
_ = ax.hist(merged_df['closest_0_dipole'].to_numpy(), bins=35, density=True,alpha=.1,color=colors[2],label='reference')
ax.spines[['right', 'top']].set_visible(False)
ax.legend(frameon=False,fontsize=8)
ax.set_xlabel('dipole moment [Debye]')
ax.set_ylabel('fraction molecules') 
ax.set_xlim([0,10])
f.savefig('figures/original_intervened_dipole_histogram.svg')
